# %% [markdown]
# # Algo 3

# %%
## Algo 3

import pandas as pd
import numpy as np

df = pd.read_csv('run_results.csv', names=['iteration', 'timestamp','fitness','dataset','matrix','algo'])

import matplotlib.pyplot as plt
plt.plot( df['iteration'],df['fitness'], 'ro')
plt.show()

# %% [markdown]
# ## Algo 4

# %%
files = df['matrix'].unique()
for f in files[:5]:
    df_matrix = df[df['matrix']==f]
    plt.plot( df_matrix['iteration'], df_matrix['fitness'], 'ro')
    plt.show()

# %% [markdown]
# ## Algo 5

# %%
files = df['matrix'].unique()
for f in files[:5]:
    df_matrix = df[df['matrix']==f]
    plt.plot( df_matrix['iteration'], df_matrix['fitness'], 'ro')
    plt.show()
